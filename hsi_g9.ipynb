# %%
import numpy as np
import pandas as pd
from spectral import *
import scipy.io as sio
import matplotlib.pyplot as plt

# %%
hsi = sio.loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']

# %%
hsi.shape
# Out:
# (145, 145, 200)

# %%
plt.imshow(hsi[:,:,9])

# %%
anypxl = hsi[100,100,:]
plt.figure(figsize=(12,6))
plt.plot(anypxl)
plt.xlim((0,300))
plt.ylim((0,8000))
plt.savefig('SS.png')

# %%
pc = principal_components(hsi)
pc_999 = pc.reduce(fraction = 0.999)

# %%
print(len(pc_999.eigenvalues))
# Out:
# 69

# %%
hsi_pca = pc_999.transform(hsi)

# %%
hsi_pca.shape
# Out:
# (145, 145, 69)

# %%
plt.imshow(hsi_pca[:,:,6])
